# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Do you wanna know how to upload URL links in Jupyter?

# %% [markdown]
# - Check the below block of cell

# %% [markdown]
# [Markdown for Jupyter Web Link](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet)

# %% [markdown]
# > This is an interesting Jupyter Notebook (Cheatsheet) for someone who likes to well document their Jupyter notebooks.
# ***
#
# ### What's in this notebook?
# - This notebook contains different types of Markdown we can use in Jupyter notebook
# - We'll learn them in step by step with an example
# - What is Markdown? Markdown in simple terms is formatting your plain text
# - How to add internal links within jupyter
# - How to upload images in jupyter notebook 🏖️
# - **Bonus:** We'll look into how to add emojis to jupyter notebooks! 🔥✔️❤️

# %% [markdown]
# ![Image](https://images.unsplash.com/photo-1499951360447-b19be8fe80f5?auto=format&fit=crop&q=60&w=600&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8N3x8Y29tcHV0ZXJ8ZW58MHx8MHx8fDA%3D)

# %% [markdown]
# ### Index:
#
# - [Basic Markups](#basic_markups)
# - [Color Note Boxes](#color_notes)
# - [How to add internal links](#internal_links)
# - [How to insert emojis 🔥✔️❤️](#emoji)
# - [How to add images](#image)

# %% [markdown]
# <a id = "basic_markups"></a>
# ## Basic Markups

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Info:</b> I'll be using Raw NBConver cell to add the information, like the below cell.
# </div>

# %% [markdown]
# ### Headings:

# %% [raw]
# Headings
# Use the number sign (#) followed by a blank space for notebook titles and section headings:
# # for titles
# ## for major headings
# ### for subheadings
# #### for 4th level subheadings

# %% [markdown]
# # Title
# ## Major Headings
# ### Subheadings
# #### 4th level subheadings

# %% [markdown]
# ### Emphasis:

# %% [raw]
# Bold text: __string__ or **string**
# Italic text: _string_ or *string*

# %% [markdown]
# **This is the Bold String**
#
# *This is the Italic String*

# %% [markdown]
# ### Monospace fonts

# %% [raw]
# `string`

# %% [markdown]
# `string`

# %% [markdown]
# ### Line breaks

# %% [raw]
# Sometimes markdown doesn’t make line breaks when you want them. To force a linebreak, use the following code: <br>

# %% [markdown]
# This is the 1st line <br> This is the 2nd line <br> Check this block

# %% [markdown]
# ### Indenting

# %% [markdown]
# > Text that will be indented when the Markdown is rendered.

# %% [markdown]
# <a id = "color_notes"></a>
# ## Color note boxes

# %% [raw]
# Note:
# 1. The class attribute (for ex: <div class="alert alert-block alert-info">) you see in the Markdown cells is predefined.
# 2. Don't remove them. Write your message in the div tag.

# %% [markdown]
# - Blue boxes (alert-info)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# - Yellow boxes (alert-warning)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# - Green boxes (alert-success)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# - Red boxes (alert-danger)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# <a id="internal_links"></a>
# ## How to add Internal Links. (links within jupyter notebook)

# %% [raw]
# You can add an ID above the section (add this where your heading is), the id should be unique to each cell:
# <a id="section_ID"></a>

# %% [raw]
# To link to a section that has an ID, use the following code:
# [Section title](#section_ID)

# %% [markdown]
# <a id="example_link"></a>
#
# #### This is the Heading where you'll be navigated to. Check this block of code

# %% [markdown]
# [This is how you navigate to the above Heading](#example_link)

# %% [markdown]
# <a id = "emoji"></a>
# ## How to Insert Emojis 🔥✔️❤️

# %% [markdown]
# [Reference link](https://medium.com/@shouke.wei/how-to-easily-insert-emoji-in-the-jupyter-notebook-36a1b77c0cb4)

# %% [markdown]
# > You can directly copy the emojis🔥 from this [emojipedia link](https://emojipedia.org/)

# %% [markdown]
# <a id = "image"></a>
# ## How to add Images

# %% [markdown]
# [Reference: Images web link](https://medium.com/@yogeshkd/four-ways-to-embed-images-in-your-jupyter-notebook-powered-blog-2d28f6d1b6e6#:~:text=Alternatively%2C%20if%20you%20want%20to,file%20into%20a%20Markdown%20cell.)

# %% [markdown]
# ### 1. Adding from URL:
#
# - Right click on the image you want to add from the web.
# - Select "Copy image address"
# - Paste the url to the below block in markdown cell

# %% [markdown]
# ![ALT_TEXT_FOR_SCREEN_READERS](https://plus.unsplash.com/premium_photo-1681422570054-9ae5b8b03e46?auto=format&fit=crop&q=80&w=1932&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D)

# %% [markdown]
# ### 2. Adding from your computer:
#
# - Just drag & drop your image into the markdown cell in jupyter notebook.
# - You're done!

# %% [markdown]
# ![Downpatrick%20Head%20Ireland.jfif](attachment:Downpatrick%20Head%20Ireland.jfif)
